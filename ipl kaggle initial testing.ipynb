# %%
import pandas as pd

# %%
train=pd.read_csv('Training.csv')
test=pd.read_csv('sample_submission.csv')

# %%
pre=pd.read_csv('Matches IPL 2008-2019.csv')
coming=pd.read_csv('Matches IPL 2020.csv')

# %%
train.shape
# Out:
# (15916, 14)

# %%
pre.shape
# Out:
# (756, 18)

# %%
train.tail()
# Out:
#                           Id  Runs  Boundaries  Six  Fifty  Hundred  Duck  \
# 15911        11415_RA Jadeja     9           1    0      0        0     0
# 15912  11415_Harbhajan Singh     0           0    0      0        0     0
# 15913        11415_RG Sharma    15           2    1      0        0     0
# 15914        11415_SN Thakur     2           0    0      0        0     0
# 15915        11415_HH Pandya    16           2    1      0        0     0
#
#        Batting_Points  Wickets  4W_Haul  5W_Haul  Maidens  Bowling_Points  \
# 15911              10        0        0        0        0               0
# 15912               0        0        0        0        0               0
# 15913              19        0        0        0        0               0
# 15914               2        2        0        0        0              50
# 15915              20        0        0        0        0               0
#
#        Total Points
# 15911            10
# 15912             0
# ...

# %%
pre.head()
# Out:
#    match_id  season        city        date                  team1  \
# 0        60    2008   Bangalore  18-04-2008  Kolkata Knight Riders
# 1        61    2008  Chandigarh  19-04-2008    Chennai Super Kings
# 2        62    2008       Delhi  19-04-2008       Rajasthan Royals
# 3        63    2008      Mumbai  20-04-2008         Mumbai Indians
# 4        64    2008     Kolkata  20-04-2008        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
pre=pre[['match_id', 'team1', 'team2', 'season']]

# %%
pre.head()
# Out:
#    match_id                  team1                        team2  season
# 0        60  Kolkata Knight Riders  Royal Challengers Bangalore    2008
# 1        61    Chennai Super Kings              Kings XI Punjab    2008
# 2        62       Rajasthan Royals             Delhi Daredevils    2008
# 3        63         Mumbai Indians  Royal Challengers Bangalore    2008
# 4        64        Deccan Chargers        Kolkata Knight Riders    2008

# %%
test.head()
# Out:
#                      Id  Total Points
# 0      1216492_AS Yadav             0
# 1     1216492_AT Rayudu             0
# 2     1216492_DL Chahar             0
# 3  1216492_F du Plessis             0
# 4     1216492_HH Pandya             0

# %%
coming.head()
# Out:
#    match_id         city       date team1 team2  \
# 0   1216492    Abu Dhabi  9/19/2020    MI   CSK
# 1   1216493  Dubai (DSC)  9/20/2020    DC  KXIP
# 2   1216534  Dubai (DSC)  9/21/2020   SRH   RCB
# 3   1216496      Sharjah  9/22/2020    RR   CSK
# 4   1216508    Abu Dhabi  9/23/2020   KKR    MI
#
#                                  venue                  umpire1  \
# 0      Sheikh Zayed Stadium, Abu Dhabi           Chris Gaffaney
# 1  Dubai International Cricket Stadium           Anil Chaudhary
# 2  Dubai International Cricket Stadium            Anil Dandekar
# 3              Sharjah Cricket Stadium  Chettithody Shamshuddin
# 4      Sheikh Zayed Stadium, Abu Dhabi           Chris Gaffaney
#
#            umpire2                umpire3
# 0  Virender Sharma          Sundaram Ravi
# 1      Nitin Menon           Paul Reiffel
# 2      Nitin Menon         Anil Chaudhary
# 3  Vineet Kulkarni  KN Ananthapadmanabhan
# 4    Sundaram Ravi        Virender Sharma

# %%
coming=coming[['match_id', 'team1', 'team2']]

# %%
coming.head()
# Out:
#    match_id team1 team2
# 0   1216492    MI   CSK
# 1   1216493    DC  KXIP
# 2   1216534   SRH   RCB
# 3   1216496    RR   CSK
# 4   1216508   KKR    MI

# %%
train['player'] = train['Id']
train['match_id'] =  train['Id']
for i in range(0, len( train)):
    train['player'][i] =  train['Id'][i].split("_")[-1]
    train['match_id'][i] = int( train['Id'][i].split('_')[:1][0])
# Out:
# <ipython-input-167-9c879ab34d8f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['player'][i] =  train['Id'][i].split("_")[-1]
# <ipython-input-167-9c879ab34d8f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['match_id'][i] = int( train['Id'][i].split('_')[:1][0])

# %%
train.head()
# Out:
#                 Id  Runs  Boundaries  Six  Fifty  Hundred  Duck  \
# 0   1_Bipul Sharma     0           0    0      0        0     0
# 1       1_DJ Hooda    16           1    1      0        0     0
# 2      1_KM Jadhav    31           5    1      0        0     0
# 3  1_Mandeep Singh    24           5    0      0        0     0
# 4   1_Yuvraj Singh    62          10    3      1        0     0
#
#    Batting_Points  Wickets  4W_Haul  5W_Haul  Maidens  Bowling_Points  \
# 0               0        1        0        0        0              25
# 1              19        1        0        0        0              25
# 2              38        0        0        0        0               0
# 3              29        0        0        0        0               0
# 4              86        0        0        0        0               0
#
#    Total Points         player match_id
# 0            25   Bipul Sharma        1
# 1            44       DJ Hooda        1
# ...

# %%
train=train[['Id', 'player', 'Total Points', 'match_id']]

# %%
train.head()
# Out:
#                 Id         player  Total Points match_id
# 0   1_Bipul Sharma   Bipul Sharma            25        1
# 1       1_DJ Hooda       DJ Hooda            44        1
# 2      1_KM Jadhav      KM Jadhav            38        1
# 3  1_Mandeep Singh  Mandeep Singh            29        1
# 4   1_Yuvraj Singh   Yuvraj Singh            86        1

# %%
test['player'] = test['Id']
test['match_id'] =  test['Id']
for i in range(0, len( test)):
    test['player'][i] =  test['Id'][i].split("_")[-1]
    test['match_id'][i] = int( test['Id'][i].split('_')[:1][0])
# Out:
# <ipython-input-171-1afce9d01210>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['player'][i] =  test['Id'][i].split("_")[-1]
# <ipython-input-171-1afce9d01210>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['match_id'][i] = int( test['Id'][i].split('_')[:1][0])

# %%
test.head()
# Out:
#                      Id  Total Points        player match_id
# 0      1216492_AS Yadav             0      AS Yadav  1216492
# 1     1216492_AT Rayudu             0     AT Rayudu  1216492
# 2     1216492_DL Chahar             0     DL Chahar  1216492
# 3  1216492_F du Plessis             0  F du Plessis  1216492
# 4     1216492_HH Pandya             0     HH Pandya  1216492

# %%
# merging player info with their respective match facts
train = pd.merge(train,pre, how = 'inner', on = 'match_id')
train.head()
# Out:
#                 Id         player  Total Points match_id                team1  \
# 0   1_Bipul Sharma   Bipul Sharma            25        1  Sunrisers Hyderabad
# 1       1_DJ Hooda       DJ Hooda            44        1  Sunrisers Hyderabad
# 2      1_KM Jadhav      KM Jadhav            38        1  Sunrisers Hyderabad
# 3  1_Mandeep Singh  Mandeep Singh            29        1  Sunrisers Hyderabad
# 4   1_Yuvraj Singh   Yuvraj Singh            86        1  Sunrisers Hyderabad
#
#                          team2  season
# 0  Royal Challengers Bangalore    2017
# 1  Royal Challengers Bangalore    2017
# 2  Royal Challengers Bangalore    2017
# 3  Royal Challengers Bangalore    2017
# 4  Royal Challengers Bangalore    2017

# %%
train.shape
# Out:
# (15916, 7)

# %%
# merging player info with their respective match facts
test = pd.merge(test,coming, how = 'inner', on = 'match_id')
test.head()
# Out:
#                      Id  Total Points        player match_id team1 team2
# 0      1216492_AS Yadav             0      AS Yadav  1216492    MI   CSK
# 1     1216492_AT Rayudu             0     AT Rayudu  1216492    MI   CSK
# 2     1216492_DL Chahar             0     DL Chahar  1216492    MI   CSK
# 3  1216492_F du Plessis             0  F du Plessis  1216492    MI   CSK
# 4     1216492_HH Pandya             0     HH Pandya  1216492    MI   CSK

# %%
team_name = { 'Kolkata Knight Riders':'KKR','Chennai Super Kings':'CSK','Rajasthan Royals':'RR','Mumbai Indians':'MI','Deccan Chargers':'SRH','Kings XI Punjab':'KXIP','Royal Challengers Bangalore':'RCB','Delhi Daredevils':'DC','Sunrisers Hyderabad':'SRH','Delhi Capitals':'DC','Rising Pune Supergiants':'RPS','Gujarat Lions':'GL','Rising Pune Supergiant':'RPS','Pune Warriors':'RPS','Kochi Tuskers Kerala':'KTK'}

# %%
# creating new data Frame
pm = pd.DataFrame()
pm['match_id']= pre['match_id']
pm['team1'] = pre['team1']
pm['team2']= pre['team2']
pm.team1.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
# mapping new team names in short form

pm.team1=pm['team1'].replace(team_name,regex=True)
pm.team2 = pm['team2'].map(team_name)
pm
# Out:
#      match_id team1 team2
# 0          60   KKR   RCB
# 1          61   CSK  KXIP
# 2          62    RR    DC
# 3          63    MI   RCB
# 4          64   SRH   KKR
# ..        ...   ...   ...
# 751     11347   KKR    MI
# 752     11412   CSK    MI
# 753     11413   SRH    DC
# 754     11414    DC   CSK
# 755     11415    MI   CSK
#
# [756 rows x 3 columns]

# %%
train.head()
# Out:
#                 Id         player  Total Points match_id                team1  \
# 0   1_Bipul Sharma   Bipul Sharma            25        1  Sunrisers Hyderabad
# 1       1_DJ Hooda       DJ Hooda            44        1  Sunrisers Hyderabad
# 2      1_KM Jadhav      KM Jadhav            38        1  Sunrisers Hyderabad
# 3  1_Mandeep Singh  Mandeep Singh            29        1  Sunrisers Hyderabad
# 4   1_Yuvraj Singh   Yuvraj Singh            86        1  Sunrisers Hyderabad
#
#                          team2  season
# 0  Royal Challengers Bangalore    2017
# 1  Royal Challengers Bangalore    2017
# 2  Royal Challengers Bangalore    2017
# 3  Royal Challengers Bangalore    2017
# 4  Royal Challengers Bangalore    2017

# %%
train=train[['Id', 'player', 'Total Points', 'match_id', 'season']]
train.head()
# Out:
#                 Id         player  Total Points match_id  season
# 0   1_Bipul Sharma   Bipul Sharma            25        1    2017
# 1       1_DJ Hooda       DJ Hooda            44        1    2017
# 2      1_KM Jadhav      KM Jadhav            38        1    2017
# 3  1_Mandeep Singh  Mandeep Singh            29        1    2017
# 4   1_Yuvraj Singh   Yuvraj Singh            86        1    2017

# %%
# merging player info with their respective match facts
train = pd.merge(train,pm, how = 'inner', on = 'match_id')
train.head()
# Out:
#                 Id         player  Total Points match_id  season team1 team2
# 0   1_Bipul Sharma   Bipul Sharma            25        1    2017   SRH   RCB
# 1       1_DJ Hooda       DJ Hooda            44        1    2017   SRH   RCB
# 2      1_KM Jadhav      KM Jadhav            38        1    2017   SRH   RCB
# 3  1_Mandeep Singh  Mandeep Singh            29        1    2017   SRH   RCB
# 4   1_Yuvraj Singh   Yuvraj Singh            86        1    2017   SRH   RCB

# %%
train.head()
# Out:
#                 Id         player  Total Points match_id  season team1 team2
# 0   1_Bipul Sharma   Bipul Sharma            25        1    2017   SRH   RCB
# 1       1_DJ Hooda       DJ Hooda            44        1    2017   SRH   RCB
# 2      1_KM Jadhav      KM Jadhav            38        1    2017   SRH   RCB
# 3  1_Mandeep Singh  Mandeep Singh            29        1    2017   SRH   RCB
# 4   1_Yuvraj Singh   Yuvraj Singh            86        1    2017   SRH   RCB

# %%
train.shape
# Out:
# (15916, 7)

# %%
test.head()
# Out:
#                      Id  Total Points        player match_id team1 team2
# 0      1216492_AS Yadav             0      AS Yadav  1216492    MI   CSK
# 1     1216492_AT Rayudu             0     AT Rayudu  1216492    MI   CSK
# 2     1216492_DL Chahar             0     DL Chahar  1216492    MI   CSK
# 3  1216492_F du Plessis             0  F du Plessis  1216492    MI   CSK
# 4     1216492_HH Pandya             0     HH Pandya  1216492    MI   CSK

# %%
test.shape
# Out:
# (1283, 6)

# %%
train_df=train[['Total Points', 'player', 'match_id', 'team1', 'team2']]
train_df.head()
# Out:
#    Total Points         player match_id team1 team2
# 0            25   Bipul Sharma        1   SRH   RCB
# 1            44       DJ Hooda        1   SRH   RCB
# 2            38      KM Jadhav        1   SRH   RCB
# 3            29  Mandeep Singh        1   SRH   RCB
# 4            86   Yuvraj Singh        1   SRH   RCB

# %%
X=train_df[['player', 'team1', 'team2']]

# %%
X.head()
# Out:
#           player team1 team2
# 0   Bipul Sharma   SRH   RCB
# 1       DJ Hooda   SRH   RCB
# 2      KM Jadhav   SRH   RCB
# 3  Mandeep Singh   SRH   RCB
# 4   Yuvraj Singh   SRH   RCB

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
X.player=le.fit_transform(X.player)

X.team1 = le.fit_transform(X.team1)
X.team2 = le.fit_transform(X.team2)
# Out:
# C:\Users\ssc\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
X.head()
# Out:
#    player  team1  team2
# 0      90     10      7
# 1     129     10      7
# 2     242     10      7
# 3     317     10      7
# 4     557     10      7

# %%
X.shape
# Out:
# (15916, 3)

# %%
y.shape
# Out:
# (15916,)

# %%
y=train_df['Total Points']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV ,RandomizedSearchCV
from sklearn.tree import plot_tree


from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
import numpy as np

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
model = LinearRegression()
model2 = SVR()
model3 = DecisionTreeRegressor( criterion="friedman_mse", splitter= 'random')
model4 = RandomForestRegressor()
model5 = AdaBoostRegressor()
model6 = GradientBoostingRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1 = model.predict(X_test)

# %%
# measure the errors

RMSE = np.sqrt(mean_squared_error(y_test,y_pred1))

RMSE
# Out:
# 29.70800309485915

# %%
model2.fit(X_train,y_train)
y_pred2 = model2.predict(X_test) 
# measure the errors

RMSE = np.sqrt(mean_squared_error(y_test,y_pred2))

RMSE
# Out:
# 30.075216890625

# %%
model3.fit(X_train,y_train)
y_pred3 = model3.predict(X_test) 
# measure the errors

RMSE = np.sqrt(mean_squared_error(y_test,y_pred3))

RMSE
# Out:
# 35.551165505293376

# %%
model4.fit(X_train,y_train)
y_pred4 = model4.predict(X_test) 
# measure the errors

RMSE = np.sqrt(mean_squared_error(y_test,y_pred4))

RMSE
# Out:
# 32.855763749649995

# %%
model5.fit(X_train,y_train)
y_pred5 = model5.predict(X_test) 
# measure the errors

RMSE = np.sqrt(mean_squared_error(y_test,y_pred5))

RMSE
# Out:
# 37.06178275036204

# %%
model6.fit(X_train,y_train)
y_pred6 = model6.predict(X_test) 
# measure the errors

RMSE = np.sqrt(mean_squared_error(y_test,y_pred6))

RMSE
# Out:
# 29.277524563898577
